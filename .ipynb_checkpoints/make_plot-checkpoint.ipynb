# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # POS Proportion

# %%
pos = {'NN': 76,
'PREP': 59,
'VB': 40,
'REL': 31,
'ADV': 29,
'DET': 20,
'ART': 18,
'NM': 7,
'QT': 1,
'etc': 6}

pos_ = dict(sorted(pos.items(), key=lambda x: x[1], reverse=True))
pos_
# Out:
# {'NN': 76,
#  'PREP': 59,
#  'VB': 40,
#  'REL': 31,
#  'ADV': 29,
#  'DET': 20,
#  'ART': 18,
#  'NM': 7,
#  'etc': 6,
#  'QT': 1}

# %%
labels = pos_.keys()
sizes = pos_.values()

# %%
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%',
       pctdistance=1.25, labeldistance=.7,
      radius=1.5)
plt.savefig(fname='fig7.png', dpi=300, format='png')
plt.show()

# %% [markdown]
# # PE - Sent Length

# %%
import os
data = [f for f in os.listdir('.') if len(f) == 5]
data
# Out:
# ['q.csv', 'p.csv', 'r.csv', 'x.csv', 'y.csv', 'z.csv']

# %%
df = pd.read_csv(data[0])
for col in df.columns:
    df[col] = df[col].astype(float)

# %%
df = df.fillna(0)

# %%
df.corr()['Segment Length']
# Out:
# Segment Length        1.000000
# Post-edit Time(ms)    0.704417
# Edit Effort           0.348892
# Name: Segment Length, dtype: float64

# %%
def clean_data(file):
    df = pd.read_csv(file)
    for col in df.columns:
        df[col] = df[col].astype(float)
    df = df.fillna(0)
    return df

# %%
result = pd.DataFrame()
for file in data:
    name = file[0].upper()
    df = clean_data(file)
    cor = df.corr()['Segment Length']
    cor = cor.drop(index='Segment Length')
    result[name] = cor
    
result
# Out:
#                            Q         P         R         X         Y         Z
# Post-edit Time(ms)  0.704417  0.742296  0.599446  0.547032  0.734816  0.067771
# Edit Effort         0.348892  0.348075  0.297453  0.287209  0.260017  0.209292

# %%
import seaborn as sns

# %%
sns.heatmap(result['P Q R X Y Z'.split()], annot=True, fmt='.3f', cmap="crest")
plt.savefig(dpi=300, fname='pe_corr.png', format='png')

# %%
import numpy as np
np.mean(result.iloc[1])
# Out:
# 0.291822841098853

# %% [markdown]
# # Edit Distance

# %%
distance = list(range(11))
d = [0.25853,	0.17585,	0.15879,	0.14304,	0.09318,	0.06824,	0.05249,	0.03543,	0.01444, 0, 0]
df2 = pd.DataFrame(data=d, index=distance, columns=['distance'])
df2
# Out:
#     distance
# 0    0.25853
# 1    0.17585
# 2    0.15879
# 3    0.14304
# 4    0.09318
# 5    0.06824
# 6    0.05249
# 7    0.03543
# 8    0.01444
# 9    0.00000
# 10   0.00000

# %%
#df2.to_csv('edit_dist.csv')

# %%
ax = df2.plot() 
for idx, label in enumerate(list(df2.index)): 
    for acc in df2.columns:
        value = np.round(df2.iloc[idx][acc],decimals=2)
        ax.annotate(value,
                    (idx, value),
                     xytext=(0, 15), 
                     textcoords='offset points')
plt.savefig(dpi=300, format='png', fname='distance.png')
plt.show()

# %% [markdown]
# # Correlation

# %%
df3 = pd.read_csv('pe_data.csv', index_col=0)
df3
# Out:
#          3       4       5       6       7       8       9      10      11  \
# PE  131.41  231.11  383.94  166.33  254.49  325.78  257.69  288.22  611.88
# T   114.96     NaN  387.45  152.88  420.33  387.82  242.97  520.12  301.46
#
#         12  ...       54       55       56       58       59       60      70  \
# PE  315.84  ...      NaN      NaN      NaN      NaN  2334.06      NaN     NaN
# T   443.20  ...  2826.11  2691.73  2408.25  2348.68  4141.40  3912.25  3737.0
#
#          72       75       82
# PE      NaN      NaN      NaN
# T   3174.38  5705.06  8737.93
#
# [2 rows x 56 columns]

# %%
df3 = df3.fillna(0)
df3
# Out:
#          3       4       5       6       7       8       9      10      11  \
# PE  131.41  231.11  383.94  166.33  254.49  325.78  257.69  288.22  611.88
# T   114.96    0.00  387.45  152.88  420.33  387.82  242.97  520.12  301.46
#
#         12  ...       54       55       56       58       59       60      70  \
# PE  315.84  ...     0.00     0.00     0.00     0.00  2334.06     0.00     0.0
# T   443.20  ...  2826.11  2691.73  2408.25  2348.68  4141.40  3912.25  3737.0
#
#          72       75       82
# PE     0.00     0.00     0.00
# T   3174.38  5705.06  8737.93
#
# [2 rows x 56 columns]

# %%
from scipy.stats import pearsonr

# %%
df_.iloc[0].values
# Out:
# array([ 131.41,  231.11,  383.94,  166.33,  254.49,  325.78,  257.69,
#         288.22,  611.88,  315.84,  336.15,  835.81, 1076.81,  579.31,
#         932.71,  319.29,  800.83,  997.27,  753.52,  733.6 ,  799.38,
#         647.26,  811.23, 1139.46,  916.37, 1231.95, 1085.11,  789.18,
#        1556.68, 2870.67, 3151.98, 1740.87,    0.  , 1740.87, 2370.54,
#        1691.82, 1116.34, 1442.71, 1737.16,    0.  , 1742.81, 1898.28,
#        1152.78,    0.  ,    0.  , 1271.48,    0.  ,    0.  ,    0.  ,
#           0.  , 2334.06,    0.  ,    0.  ,    0.  ,    0.  ,    0.  ])

# %%
pearsonr(sent_len, df_.iloc[0].values)
# Out:
# PearsonRResult(statistic=-0.024402387519744384, pvalue=0.8583157185773147)

# %%
pearsonr(sent_len, df_.iloc[1].values)
# Out:
# PearsonRResult(statistic=0.7031102828184963, pvalue=1.5230787507531044e-09)
